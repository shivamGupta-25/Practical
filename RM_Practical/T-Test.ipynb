# %% [markdown]
# #### T-Test

# %%
from scipy.stats import ttest_ind

group1 = [78, 85, 92, 88, 75] 
group2 = [70, 65, 80, 72, 68] 
t_stat, p_value = ttest_ind(group1, group2)

print("t-statistic:", t_stat) 
print("p-value:", p_value)
# Out:
# t-statistic: 3.124714009053688
# p-value: 0.014127666460539996

# %% [markdown]
# #### The test scores significantly improved after using the new study technique.

# %%
from scipy.stats import ttest_rel 
before = [70, 68, 80, 72, 65, 74] 
after  = [75, 74, 85, 78, 70, 79] 
t_stat, p_value = ttest_rel(after, before) 
print("t-statistic:", t_stat) 
print("p-value:", p_value)
# Out:
# t-statistic: 25.298221281347033
# p-value: 1.8014023722499407e-06

# %% [markdown]
# #### ANOVA

# %%
import scipy.stats as stats 
method_a = [85, 90, 88, 75, 95] 
method_b = [78, 74, 80, 76, 82] 
method_c = [82, 88, 85, 90, 87] 
f_stat, p_value = stats.f_oneway(method_a, method_b, method_c)

print("F-statistic:", f_stat) 
print("p-value:", p_value)
# Out:
# F-statistic: 4.844504021447721
# p-value: 0.028684635622610286

# %% [markdown]
# #### Chi-Square Goodness of Fit Test

# %%
# importing packages

import scipy.stats as stats
import numpy as np

# no of hours a student studies
# in a week vs expected no of hours
observed_data = [8, 6, 10, 7, 8, 11, 9]
expected_data = [9, 8, 11, 8, 10, 7, 6]

# Chi-Square Goodness of Fit Test
chi_square_test_statistic, p_value = stats.chisquare(
observed_data, expected_data)
# chi square test statistic and p value

print('chi_square_test_statistic is : ' + str(chi_square_test_statistic))
print('p_value : ' + str(p_value))

# find Chi-Square critical value
print(stats.chi2.ppf(1-0.05, df=6))
# Out:
# chi_square_test_statistic is : 5.0127344877344875
# p_value : 0.542180861413329
# 12.591587243743977
